# %%
class Date:
    def __init__(self, day: int, month: int, year: int):
        self.day = day
        self.month = month
        self.year = year

    def display(self):
        print(f"{self.day}/{self.month}/{self.year}")

# %%
class Employee:
    def __init__(self, name:str,birth:Date,hire:Date):
        self.name = name
        self.birth = birth
        self.hire = hire

    def display(self):
        print("Tên:",self.name)
        print("Ngày sinh:",end=" ");self.birth.display()
        print("Ngày vào công ty:",end=" ");self.hire.display()

# %%
birth = Date(1,1,2006)
hire =Date(6,10,2025)
nv = Employee("Nguyễn Văn Y",birth,hire)
nv.display()
# Out:
# Tên: Nguyễn Văn Y
# Ngày sinh: 1/1/2006
# Ngày vào công ty: 6/10/2025
